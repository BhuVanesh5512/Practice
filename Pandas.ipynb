# %%
#pandas build on numpy
#pandas = panel data
#usually works with data series

# %%
import pandas as pd

# %%
#Series :1-D datatype of labelled array (column) in a spreadsheet
data1 = [100,102, 104]#int
data2 = ["A","B","c"]#string =object
data3 =[True,False]#boolean
series = pd.Series(data1)
series1 =pd.Series(data2)
series2 =pd.Series(data3)
print(series)
print(series1)
print(series2)
# Out:
# 0    100
# 1    102
# 2    104
# dtype: int64
# 0    A
# 1    B
# 2    c
# dtype: object
# 0     True
# 1    False
# dtype: bool

# %%
series
# Out:
# 0    100
# 1    102
# 2    104
# dtype: int64

# %%
series =pd.Series(data1, index =["a","b","c"])#index change / label change
print(series)
# Out:
# a    100
# b    102
# c    104
# dtype: int64

# %%
print(series.loc["a"])#used to retrive from the value by label (location)
series.loc["c"]= 200
print(series)
# Out:
# 100
# a    100
# b    102
# c    200
# dtype: int64

# %%
print(series.iloc[0])#used by integer label
# Out:
# 100

# %%
data = [100,200,300,400,500]#filtering by value
series3 = pd.Series(data , index = ["a","b","c","d","e"])
print(series3[series3 > 200])
# Out:
# c    300
# d    400
# e    500
# dtype: int64

# %%
data4 = {"Day1": 1750, "Day2": 2100, "Day3":1700}
series4 = pd.Series(data4)
print(series4.loc["Day1"])
print(series4.iloc[2])
series4.loc["Day1"] +=400
print(series4)
print(series4[series4 >2000])
# Out:
# 1750
# 1700
# Day1    2150
# Day2    2100
# Day3    1700
# dtype: int64
# Day1    2150
# Day2    2100
# dtype: int64

# %%
#Datarframe = Atabular data Structure with rows and columns.(2-D) same as spread sheet
data = {"Name" : ["Luffy", "Zoro", "Sanji"],
        "Age" : [19 ,22, 22]}
df = pd.DataFrame(data, index =["Captian", "Vice-Captian", "Cook"])
print(df)
# Out:
#                Name  Age
# Captian       Luffy   19
# Vice-Captian   Zoro   22
# Cook          Sanji   22

# %%
print(df.loc["Captian"])#For Single Row by label
# Out:
# Name    Luffy
# Age        19
# Name: Captian, dtype: object

# %%
print(df.iloc[1])#same with index
print(df.iloc[2])
# Out:
# Name    Zoro
# Age       22
# Name: Vice-Captian, dtype: object
# Name    Sanji
# Age        22
# Name: Cook, dtype: object

# %%
#Add new Column
df["Joining"] = ["Captian", "Crew1", "Crew3"]
print(df)
# Out:
#                Name  Age  Joining
# Captian       Luffy   19  Captian
# Vice-Captian   Zoro   22    Crew1
# Cook          Sanji   22    Crew3

# %%
#Add new Row : create new dataframe and concatenate
new_row = pd.DataFrame([{"Name":"Nami", "Age": 21,"Joining" : "Crew2" }], index =["Navigator"])
df = pd.concat([df ,new_row])#used to concatenate
print(df)
# Out:
#                Name  Age  Joining
# Captian       Luffy   19  Captian
# Vice-Captian   Zoro   22    Crew1
# Cook          Sanji   22    Crew3
# Navigator      Nami   21    Crew2

# %%
#importing
#we read by using pd.read_csv()
#for json: pd.read_json

# %%
df = pd.read_csv("data.csv")
print(df)
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire     NaN     0.6     8.5          0
# 4      5  Charmeleon     Fire     NaN     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 145  146     Moltres     Fire  Flying     2.0    60.0          1
# 146  147     Dratini   Dragon     NaN     1.8     3.3          0
# 147  148   Dragonair   Dragon     NaN     4.0    16.5          0
# 148  149   Dragonite   Dragon  Flying     2.2   210.0          0
# 149  150      Mewtwo  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 7 columns]

# %%
print(df.to_string())
# Out:
#       No        Name     Type1     Type2  Height  Weight  Legendary
# 0      1   Bulbasaur     Grass    Poison     0.7     6.9          0
# 1      2     Ivysaur     Grass    Poison     1.0    13.0          0
# 2      3    Venusaur     Grass    Poison     2.0   100.0          0
# 3      4  Charmander      Fire       NaN     0.6     8.5          0
# 4      5  Charmeleon      Fire       NaN     1.1    19.0          0
# 5      6   Charizard      Fire    Flying     1.7    90.5          0
# 6      7    Squirtle     Water       NaN     0.5     9.0          0
# 7      8   Wartortle     Water       NaN     1.0    22.5          0
# 8      9   Blastoise     Water       NaN     1.6    85.5          0
# 9     10    Caterpie       Bug       NaN     0.3     2.9          0
# 10    11     Metapod       Bug       NaN     0.7     9.9          0
# 11    12  Butterfree       Bug    Flying     1.1    32.0          0
# 12    13      Weedle       Bug    Poison     0.3     3.2          0
# ...

# %%
#selection
#by column
print(df["Name"])
print(df["Height"])
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 145       Moltres
# 146       Dratini
# 147     Dragonair
# 148     Dragonite
# 149        Mewtwo
# Name: Name, Length: 150, dtype: object
# 0      0.7
# 1      1.0
# 2      2.0
# 3      0.6
# 4      1.1
#       ...
# 145    2.0
# 146    1.8
# 147    4.0
# 148    2.2
# 149    2.0
# Name: Height, Length: 150, dtype: float64

# %%
print(df[["Name","Height","Weight"]])
# Out:
#            Name  Height  Weight
# 0     Bulbasaur     0.7     6.9
# 1       Ivysaur     1.0    13.0
# 2      Venusaur     2.0   100.0
# 3    Charmander     0.6     8.5
# 4    Charmeleon     1.1    19.0
# ..          ...     ...     ...
# 145     Moltres     2.0    60.0
# 146     Dratini     1.8     3.3
# 147   Dragonair     4.0    16.5
# 148   Dragonite     2.2   210.0
# 149      Mewtwo     2.0   122.0
#
# [150 rows x 3 columns]

# %%
#Selection 
#By rows
print(df.loc[123])
# Out:
# No               124
# Name            Jynx
# Type1            Ice
# Type2        Psychic
# Height           1.4
# Weight          40.6
# Legendary          0
# Name: 123, dtype: object

# %%
#to set a column as index
df = pd.read_csv("data.csv",index_col = "Name")
print(df)
# Out:
#              No    Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur     1    Grass  Poison     0.7     6.9          0
# Ivysaur       2    Grass  Poison     1.0    13.0          0
# Venusaur      3    Grass  Poison     2.0   100.0          0
# Charmander    4     Fire     NaN     0.6     8.5          0
# Charmeleon    5     Fire     NaN     1.1    19.0          0
# ...         ...      ...     ...     ...     ...        ...
# Moltres     146     Fire  Flying     2.0    60.0          1
# Dratini     147   Dragon     NaN     1.8     3.3          0
# Dragonair   148   Dragon     NaN     4.0    16.5          0
# Dragonite   149   Dragon  Flying     2.2   210.0          0
# Mewtwo      150  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 6 columns]

# %%
print(df.loc["Pikachu"])
# Out:
# No                 25
# Type1        Electric
# Type2             NaN
# Height            0.4
# Weight            6.0
# Legendary           0
# Name: Pikachu, dtype: object

# %%
#customize row selection
print(df.loc["Charizard" ,["Height", "Weight"]])
# Out:
# Height     1.7
# Weight    90.5
# Name: Charizard, dtype: object

# %%
print(df.loc["Charizard" : "Blastoise" ,["Height", "Weight"]]) # index tpo index
print(df.iloc[0:12:2, 1:4])#specified column selection
# Out:
#            Height  Weight
# Name
# Charizard     1.7    90.5
# Squirtle      0.5     9.0
# Wartortle     1.0    22.5
# Blastoise     1.6    85.5
#             Type1   Type2  Height
# Name
# Bulbasaur   Grass  Poison     0.7
# Venusaur    Grass  Poison     2.0
# Charmeleon   Fire     NaN     1.1
# Squirtle    Water     NaN     0.5
# Blastoise   Water     NaN     1.6
# Metapod       Bug     NaN     0.7

# %%
#fun
pokemon = input("Enter a Pokemon Name: ")

try:
    print(df.loc[pokemon])
except KeyError:
    print(f"{pokemon} not found in this")
# Out:
# ddfffdd not found in this

# %%
print(df[df["Height"]<=2])
# Out:
#              No     Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur     1     Grass  Poison     0.7     6.9          0
# Ivysaur       2     Grass  Poison     1.0    13.0          0
# Venusaur      3     Grass  Poison     2.0   100.0          0
# Charmander    4      Fire     NaN     0.6     8.5          0
# Charmeleon    5      Fire     NaN     1.1    19.0          0
# ...         ...       ...     ...     ...     ...        ...
# Articuno    144       Ice  Flying     1.7    55.4          1
# Zapdos      145  Electric  Flying     1.6    52.6          1
# Moltres     146      Fire  Flying     2.0    60.0          1
# Dratini     147    Dragon     NaN     1.8     3.3          0
# Mewtwo      150   Psychic     NaN     2.0   122.0          1
#
# [142 rows x 6 columns]

# %%
#filtering
#keeping the rows, that match the contion
Heavy_Pokemon = df[df["Weight"] > 50.0]
print(Heavy_Pokemon)
# Out:
#              No     Type1     Type2  Height  Weight  Legendary
# Name
# Venusaur      3     Grass    Poison     2.0   100.0          0
# Charizard     6      Fire    Flying     1.7    90.5          0
# Blastoise     9     Water       NaN     1.6    85.5          0
# Arbok        24    Poison       NaN     3.5    65.0          0
# Nidoqueen    31    Poison    Ground     1.3    60.0          0
# Nidoking     34    Poison    Ground     1.4    62.0          0
# Golbat       42    Poison    Flying     1.6    55.0          0
# Golduck      55     Water       NaN     1.7    76.6          0
# Arcanine     59      Fire       NaN     1.9   155.0          0
# Poliwrath    62     Water  Fighting     1.3    54.0          0
# Kadabra      64   Psychic       NaN     1.3    56.5          0
# Machoke      67  Fighting       NaN     1.5    70.5          0
# Machamp      68  Fighting       NaN     1.6   130.0          0
# Tentacruel   73     Water    Poison     1.6    55.0          0
# ...

# %%
#fun
legendary_pokemon =df[df["Legendary"] == 1]
print(legendary_pokemon)
# Out:
#            No     Type1   Type2  Height  Weight  Legendary
# Name
# Articuno  144       Ice  Flying     1.7    55.4          1
# Zapdos    145  Electric  Flying     1.6    52.6          1
# Moltres   146      Fire  Flying     2.0    60.0          1
# Mewtwo    150   Psychic     NaN     2.0   122.0          1

# %%
#aggregate functions :reduce a set of value into single summary value
#used to summarize and analyze data 


#For whole set of data
print(df.mean(numeric_only= True))
print(df.sum(numeric_only= True))
print(df.min(numeric_only= True))
print(df.count())
print(df.max(numeric_only= True))
# Out:
# No           75.500000
# Height        1.200000
# Weight       46.231333
# Legendary     0.026667
# dtype: float64
# No           11325.0
# Height         180.0
# Weight        6934.7
# Legendary        4.0
# dtype: float64
# No           1.0
# Height       0.2
# Weight       0.1
# Legendary    0.0
# dtype: float64
# No           150
# Type1        150
# Type2         67
# Height       150
# Weight       150
# Legendary    150
# dtype: int64
# No           150.0
# Height         8.8
# Weight       460.0
# Legendary      1.0
# dtype: float64

# %%
#For single column 
print(df["Height"].min())
# Out:
# 0.2

# %%
#groupby() function
group = df.groupby("Type1")
print(group)

# %%
print(group["Height"].max())
# Out:
# Type1
# Bug         1.5
# Dragon      4.0
# Electric    1.6
# Fairy       1.3
# Fighting    1.6
# Fire        2.0
# Ghost       1.6
# Grass       2.0
# Ground      1.9
# Ice         1.7
# Normal      2.2
# Poison      3.5
# Psychic     2.0
# Rock        8.8
# Water       6.5
# Name: Height, dtype: float64

# %%
#Data Cleaning : Process of fixing/removing incomplete or irrelevant data.
dc =df.drop(columns =["Legendary", "No"])
print(dc)
# Out:
#               Type1   Type2  Height  Weight
# Name
# Bulbasaur     Grass  Poison     0.7     6.9
# Ivysaur       Grass  Poison     1.0    13.0
# Venusaur      Grass  Poison     2.0   100.0
# Charmander     Fire     NaN     0.6     8.5
# Charmeleon     Fire     NaN     1.1    19.0
# ...             ...     ...     ...     ...
# Moltres        Fire  Flying     2.0    60.0
# Dratini      Dragon     NaN     1.8     3.3
# Dragonair    Dragon     NaN     4.0    16.5
# Dragonite    Dragon  Flying     2.2   210.0
# Mewtwo      Psychic     NaN     2.0   122.0
#
# [150 rows x 4 columns]

# %%
dp = df.dropna(subset =["Type2"])
print(dp)
# Out:
#              No     Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur     1     Grass  Poison     0.7     6.9          0
# Ivysaur       2     Grass  Poison     1.0    13.0          0
# Venusaur      3     Grass  Poison     2.0   100.0          0
# Charizard     6      Fire  Flying     1.7    90.5          0
# Butterfree   12       Bug  Flying     1.1    32.0          0
# ...         ...       ...     ...     ...     ...        ...
# Aerodactyl  142      Rock  Flying     1.8    59.0          0
# Articuno    144       Ice  Flying     1.7    55.4          1
# Zapdos      145  Electric  Flying     1.6    52.6          1
# Moltres     146      Fire  Flying     2.0    60.0          1
# Dragonite   149    Dragon  Flying     2.2   210.0          0
#
# [67 rows x 6 columns]

# %%
fn =df.fillna({"Type2":"None"})#used to replace missing values
print(fn)
# Out:
#              No    Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur     1    Grass  Poison     0.7     6.9          0
# Ivysaur       2    Grass  Poison     1.0    13.0          0
# Venusaur      3    Grass  Poison     2.0   100.0          0
# Charmander    4     Fire    None     0.6     8.5          0
# Charmeleon    5     Fire    None     1.1    19.0          0
# ...         ...      ...     ...     ...     ...        ...
# Moltres     146     Fire  Flying     2.0    60.0          1
# Dratini     147   Dragon    None     1.8     3.3          0
# Dragonair   148   Dragon    None     4.0    16.5          0
# Dragonite   149   Dragon  Flying     2.2   210.0          0
# Mewtwo      150  Psychic    None     2.0   122.0          1
#
# [150 rows x 6 columns]

# %%
#fix inconsistent values
df["Type1"] = df["Type1"].replace({"Grass" : "GRASS","Fire" :"FIRE"})
print(df)
# Out:
#              No    Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur     1    GRASS  Poison     0.7     6.9          0
# Ivysaur       2    GRASS  Poison     1.0    13.0          0
# Venusaur      3    GRASS  Poison     2.0   100.0          0
# Charmander    4     FIRE     NaN     0.6     8.5          0
# Charmeleon    5     FIRE     NaN     1.1    19.0          0
# ...         ...      ...     ...     ...     ...        ...
# Moltres     146     FIRE  Flying     2.0    60.0          1
# Dratini     147   Dragon     NaN     1.8     3.3          0
# Dragonair   148   Dragon     NaN     4.0    16.5          0
# Dragonite   149   Dragon  Flying     2.2   210.0          0
# Mewtwo      150  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 6 columns]

# %%
#Standardize text
df["Type1"] = df["Type1"].str.lower()
print(df)
# Out:
#              No    Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur     1    grass  Poison     0.7     6.9          0
# Ivysaur       2    grass  Poison     1.0    13.0          0
# Venusaur      3    grass  Poison     2.0   100.0          0
# Charmander    4     fire     NaN     0.6     8.5          0
# Charmeleon    5     fire     NaN     1.1    19.0          0
# ...         ...      ...     ...     ...     ...        ...
# Moltres     146     fire  Flying     2.0    60.0          1
# Dratini     147   dragon     NaN     1.8     3.3          0
# Dragonair   148   dragon     NaN     4.0    16.5          0
# Dragonite   149   dragon  Flying     2.2   210.0          0
# Mewtwo      150  psychic     NaN     2.0   122.0          1
#
# [150 rows x 6 columns]

# %%
#fix datatype
df["Legendary"] = df["Legendary"].astype(bool)
print(df)
# Out:
#              No    Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur     1    grass  Poison     0.7     6.9      False
# Ivysaur       2    grass  Poison     1.0    13.0      False
# Venusaur      3    grass  Poison     2.0   100.0      False
# Charmander    4     fire     NaN     0.6     8.5      False
# Charmeleon    5     fire     NaN     1.1    19.0      False
# ...         ...      ...     ...     ...     ...        ...
# Moltres     146     fire  Flying     2.0    60.0       True
# Dratini     147   dragon     NaN     1.8     3.3      False
# Dragonair   148   dragon     NaN     4.0    16.5      False
# Dragonite   149   dragon  Flying     2.2   210.0      False
# Mewtwo      150  psychic     NaN     2.0   122.0       True
#
# [150 rows x 6 columns]

# %%
#remove duplicates
df =pd.read_csv("data.csv")
print(df)
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire     NaN     0.6     8.5          0
# 4      5  Charmeleon     Fire     NaN     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 153  150      Mewtwo  Psychic     NaN     2.0   122.0          1
# 154  150      Mewtwo  Psychic     NaN     2.0   122.0          1
# 155  150      Mewtwo  Psychic     NaN     2.0   122.0          1
# 156  150      Mewtwo  Psychic     NaN     2.0   122.0          1
# 157  150      Mewtwo  Psychic     NaN     2.0   122.0          1
#
# [158 rows x 7 columns]

# %%
df =df.drop_duplicates()
print(df)
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire     NaN     0.6     8.5          0
# 4      5  Charmeleon     Fire     NaN     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 149  146     Moltres     Fire  Flying     2.0    60.0          1
# 150  147     Dratini   Dragon     NaN     1.8     3.3          0
# 151  148   Dragonair   Dragon     NaN     4.0    16.5          0
# 152  149   Dragonite   Dragon  Flying     2.2   210.0          0
# 153  150      Mewtwo  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 7 columns]
