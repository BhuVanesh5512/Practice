# %%
import numpy as np

# %%
# array creation by numpy
arr =np.array([1,2,3,4,5])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr1 = np.array([[1,2,3],
                 [4,5,6]])

# %%
arr1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
type(arr1)
# Out:
# numpy.ndarray
